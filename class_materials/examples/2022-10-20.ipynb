# %% [markdown]
# # 2022-10-20

# %%
car_models = {"audi": "100", "bwm": "e63", "tesla": "model3"}
print(car_models["audi"])
print(car_models["tesla"])
print(car_models["citroen"])
# Out:
# 100
# model3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [3], line 4
#       2 print(car_models["audi"])
#       3 print(car_models["tesla"])
# ----> 4 print(car_models["citroen"])
#
# KeyError: 'citroen'

# %%
print(2 + 2)
print(2 * 2)
print(2 / 0)
# Out:
# 4
# 4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [6], line 3
#       1 print(2 + 2)
#       2 print(2 * 2)
# ----> 3 print(2 / 0)
#
# ZeroDivisionError: division by zero

# %%
class Student:
    def __init__(self):
        self._name = "Dominykas"
    
    def speak(self):
        print("Hello, I am speaking!")

student = Student()
student.speak()
student.sit()
# Out:
# Hello, I am speaking!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 10
#       8 student = Student()
#       9 student.speak()
# ---> 10 student.sit()
#
# AttributeError: 'Student' object has no attribute 'sit'

# %%
car_models = {"audi": "100", "bwm": "e63", "tesla": "model3"}

try:
    print(car_models["audi"])
    print(car_models["citroen"])
    print(car_models["tesla"])
except:
    print("The key does not exist!")
# Out:
# 100
# The key does not exist!

# %%
car_models = {"audi": "100", "bwm": "e63", "tesla": "model3"}

for brand in ["audi", "citroen", "tesla"]:
    print(car_models[brand])

# %%
car_models = {"audi": "100", "bwm": "e63", "tesla": "model3"}

for brand in ["audi", "citroen", "tesla"]:
    try:
        print(car_models[brand])
        print(f"The {brand} goes brr!")
    except:
        print("The key does not exist!")
# Out:
# 100
# The audi goes brr!
# The key does not exist!
# model3
# The tesla goes brr!

# %%
car_models = {"audi": "100", "bwm": "e63", "tesla": "model3"}

for brand in ["audi", "citroen", "tesla"]:
    try:
        print(car_models[brand])
        print(f"The {brand} goes brr!")
    except:
        print("The key does not exist!")
    print(f"Current brand is {brand}")
# Out:
# 100
# The audi goes brr!
# The audi goes brr!
# Current brand is audi
# The key does not exist!
# The citroen goes brr!
# Current brand is citroen
# model3
# The tesla goes brr!
# The tesla goes brr!
# Current brand is tesla

# %%
car_models = {"audi": "100", "bwm": "e63", "tesla": "model3"}

for brand in ["audi", "citroen", "tesla"]:
    try:
        print(car_models[brand])
        print(f"The {brand} goes brr!")
    except Exception as e:
        print("The key does not exist!", e)
    print(f"Current brand is {brand}")
# Out:
# 100
# The audi goes brr!
# Current brand is audi
# The key does not exist! 'citroen'
# Current brand is citroen
# model3
# The tesla goes brr!
# Current brand is tesla

# %%
try:
    print(2 + 2)
    print(2 * 2)
    print(2 / 0)
except Exception as e:
    print(e)
# Out:
# 4
# 4
# division by zero

# %%
from typing import Optional
import numpy as np

def check_how_much_younger_you_are(age: int, name: str) -> Optional[float]:
    family = {
        "Dominykas": 43,
        "Lukas": 20,
        "Povilas": 13,
        "Justina": 34,
        "Juste": 0
    }
    try:
        return age / family[name]
    except ZeroDivisionError as e:
        print("Sorry we tried to divide your age by someone who is still a newborn :(")
        return np.Inf
    except KeyError as e:
        print(f"The provided name {name} does not exist in the family tree. {family.keys()}")
        return None

for name in ["Dominykas", "Juste", "Antanu"]:
    print(check_how_much_younger_you_are(24, name))
# Out:
# 0.5581395348837209
# Sorry we tried to divide your age by someone who is still a newborn :(
# inf
# The provided name Antanu does not exist in the family tree. dict_keys(['Dominykas', 'Lukas', 'Povilas', 'Justina', 'Juste'])
# None
# The provided name <__main__.Student object at 0x1089f4fa0> does not exist in the family tree. dict_keys(['Dominykas', 'Lukas', 'Povilas', 'Justina', 'Juste'])
# None

# %%
from typing import Optional
import numpy as np

def check_how_much_younger_you_are(age: int, name: str) -> Optional[float]:
    family = {
        "Dominykas": 43,
        "Lukas": 20,
        "Povilas": 13,
        "Justina": 34,
        "Juste": 0
    }
    try:
        family_person_age = family[name]
    except KeyError as e:
        print(f"The provided name {name} does not exist in the family tree. {family.keys()}")
        return None
    try:
        return age / family_person_age
    except ZeroDivisionError as e:
        print("Sorry we tried to divide your age by someone who is still a newborn :(")
        return np.Inf

for name in ["Dominykas", "Juste", "Antanu"]:
    print(check_how_much_younger_you_are(24, name))
# Out:
# 0.5581395348837209
# Sorry we tried to divide your age by someone who is still a newborn :(
# inf
# The provided name Antanu does not exist in the family tree. dict_keys(['Dominykas', 'Lukas', 'Povilas', 'Justina', 'Juste'])
# None

# %%
try:
    import tensorflow as pkg
except ImportError:
    import numpy as pkg

# %%
from typing import Any, List


def return_value_from_list(_list: List[Any], index: int) -> Any:
    try:
        return _list[index]
    except IndexError:
        print("Sorry, the value is out of the list's range. Returning last list's value instead")
        return _list[-1]

return_value_from_list([1, 2, 3, 4, 5], 1)
return_value_from_list([1, 2, 3, 4, 5], 10)
# Out:
# Sorry, the value is out of the list's range. Returning last list's value instead
# 5

# %%
def add(a: int, b: int) -> int:
    if a > 100 or b > 100:
        raise Exception("The provided value must be less that 0")
    return a + b

add(10, 10)
add(200, 10)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In [42], line 7
#       4     return a + b
#       6 add(10, 10)
# ----> 7 add(200, 10)
#
# Cell In [42], line 3, in add(a, b)
#       1 def add(a: int, b: int) -> int:
#       2     if a > 100 or b > 100:
# ----> 3         raise Exception("The provided value must be less that 0")
#       4     return a + b
#
# Exception: The provided value must be less that 0

# %%
from typing import Any, List


def return_value_from_list(_list: List[Any], index: int) -> Any:
    try:
        return _list[index]
    except IndexError:
        raise IndexError("The list is too short :((")

return_value_from_list([1, 2, 3, 4, 5], 1)
return_value_from_list([1, 2, 3, 4, 5], 10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [45], line 6, in return_value_from_list(_list, index)
#       5 try:
# ----> 6     return _list[index]
#       7 except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In [45], line 11
#       8         raise IndexError("The list is too short :((")
#      10 return_value_from_list([1, 2, 3, 4, 5], 1)
# ---> 11 return_value_from_list([1, 2, 3, 4, 5], 10)
#
# Cell In [45], line 8, in return_value_from_list(_list, index)
#       6     return _list[index]
#       7 except IndexError:
# ----> 8     raise IndexError("The list is too short :((")
#
# IndexError: The list is too short :((

# %%
from typing import Optional
import numpy as np

def check_how_much_younger_you_are(age: int, name: str) -> Optional[float]:
    family = {
        "Dominykas": 43,
        "Lukas": 20,
        "Povilas": 13,
        "Justina": 34,
        "Juste": 0
    }
    try:
        assert family[name] > 0
    except AssertionError:
        print("Age is less or eq to 0!")
    try:
        return age / family[name]
    except ZeroDivisionError as e:
        print("Sorry we tried to divide your age by someone who is still a newborn :(")
        return np.Inf
    except KeyError as e:
        print(f"The provided name {name} does not exist in the family tree. {family.keys()}")
        return None

for name in ["Dominykas", "Juste", "Antanu"]:
    print(check_how_much_younger_you_are(24, name))
# Out:
# 0.5581395348837209
# Age is less or eq to 0!
# Sorry we tried to divide your age by someone who is still a newborn :(
# inf
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [47], line 26
#      23         return None
#      25 for name in ["Dominykas", "Juste", "Antanu"]:
# ---> 26     print(check_how_much_younger_you_are(24, name))
#
# Cell In [47], line 13, in check_how_much_younger_you_are(age, name)
#       5 family = {
#       6     "Dominykas": 43,
#       7     "Lukas": 20,
#    (...)
#      10     "Juste": 0
#      11 }
#      12 try:
# ---> 13     assert family[name] > 0
#      14 except AssertionError:
#      15     print("Age is less or eq to 0!")
#
# KeyError: 'Antanu'

# %%
def add(a: int, b: int) -> int:
    try:
        a = int(a)
        b = int(b)
    except TypeError:
        print("Channot convert values to int!")
    return a + b

def add(a: int, b: int) -> int:
    return a + b

def test_add():
    assert add(10, 20) == 30
    assert add(30, 40.1) == 70

test_add()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [53], line 16
#      13     assert add(10, 20) == 30
#      14     assert add(30, 40.1) == 70
# ---> 16 test_add()
#
# Cell In [53], line 14, in test_add()
#      12 def test_add():
#      13     assert add(10, 20) == 30
# ---> 14     assert add(30, 40.1) == 70
#
# AssertionError:
